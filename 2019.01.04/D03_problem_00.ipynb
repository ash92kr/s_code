# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-45000',
#  '24H_fluctate_rate': '-1.04',
#  'average_price': '4300947.4608',
#  'buy_price': '4276000',
#  'closing_price': '4275000',
#  'date': '1546568832112',
#  'max_price': '4339000',
#  'min_price': '4250000',
#  'opening_price': '4320000',
#  'sell_price': '4278000',
#  'units_traded': '18055.68376827',
#  'volume_1day': '18055.68376827',
#  'volume_7day': '56224.25563717'}

# %%
# 아래에 코드를 작성하세요.

opening = int(btc["opening_price"])
minus = int(btc["max_price"]) - int(btc["min_price"])

if opening + minus > int(btc["max_price"]):
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %%
bdp = float(btc["max_price"]) - float(btc["min_price"])

if int(btc['opening_price']) + bdp > float(btc["max_price"]):
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-7.2',
#          '24H_fluctate_rate': '-6.99',
#          'average_price': '103.243',
#          'buy_price': '95.4',
#          'closing_price': '95.8',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '103',
#          'sell_price': '95.8',
#          'units_traded': '11458747.96871732',
#          'volume_1day': '11458747.96871732',
#          'volume_7day': '50518228.348695697921657788'},
#  'ADA': {'24H_fluctate': '-2.1',
#          '24H_fluctate_rate': '-2.70',
#          'average_price': '77.1755',
#          'buy_price': '75.5',
#          'closing_price': '75.5',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.6',
#          'sell_price': '76.3',
#          'units_traded': '2078222.53756183',
#          'volume_1day': '2078222.53756183',
#          'volume_7day': '39743824.63685277'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-40',
#         '24H_fluctate_rate': '-2.43',
#         'average_price': '1632.4907',
#         'buy_price': '1610',
#         'closing_price': '1603',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1643',
#         'sell_price': '1621',
#         'units_traded': '67734.76755548',
#         'volume_1day': '67734.76755548',
#         'volume_7day': '1897917.775737726162182133'},
#  'AMO': {'24H_fluctate': '-0.18',
#          '24H_fluctate_rate': '-10.28',
#          'average_price': '1.6945',
#          'buy_price': '1.56',
#          'closing_price': '1.57',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.75',
#          'sell_price': '1.57',
#          'units_traded': '705271887.76326068',
#          'volume_1day': '705271887.76326068',
#          'volume_7day': '24112468138.230291963542864948'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.01',
#          'average_price': '147.0556',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '149',
#          'sell_price': '147',
#          'units_traded': '1511325.25549052',
#          'volume_1day': '1511325.25549052',
#          'volume_7day': '7018751.570910630100902915'},
#  'BCD': {'24H_fluctate': '-32',
#          '24H_fluctate_rate': '-3.10',
#          'average_price': '1015.7418',
#          'buy_price': '1000',
#          'closing_price': '1000',
#          'max_price': '1040',
#          'min_price': '997',
#          'opening_price': '1032',
#          'sell_price': '1001',
#          'units_traded': '120357.91275646',
#          'volume_1day': '120357.91275646',
#          'volume_7day': '1810103.60620526'},
#  'BCH': {'24H_fluctate': '-11300',
#          '24H_fluctate_rate': '-5.91',
#          'average_price': '183788.6538',
#          'buy_price': '179700',
#          'closing_price': '179600',
#          'max_price': '191500',
#          'min_price': '177300',
#          'opening_price': '190900',
#          'sell_price': '179800',
#          'units_traded': '46247.78993284',
#          'volume_1day': '46247.78993284',
#          'volume_7day': '552880.52661516'},
#  'BHPC': {'24H_fluctate': '-14',
#           '24H_fluctate_rate': '-1.54',
#           'average_price': '909.6184',
#           'buy_price': '894',
#           'closing_price': '894',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '908',
#           'sell_price': '898',
#           'units_traded': '488667.59905765',
#           'volume_1day': '488667.59905765',
#           'volume_7day': '8377330.001161527652769304'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-4600',
#          '24H_fluctate_rate': '-4.43',
#          'average_price': '100408.7797',
#          'buy_price': '99000',
#          'closing_price': '99200',
#          'max_price': '104100',
#          'min_price': '97400',
#          'opening_price': '103800',
#          'sell_price': '99200',
#          'units_traded': '23167.21842066',
#          'volume_1day': '23167.21842066',
#          'volume_7day': '269320.66246854'},
#  'BTC': {'24H_fluctate': '-45000',
#          '24H_fluctate_rate': '-1.04',
#          'average_price': '4300945.0455',
#          'buy_price': '4274000',
#          'closing_price': '4275000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4320000',
#          'sell_price': '4275000',
#          'units_traded': '18057.28376827',
#          'volume_1day': '18057.28376827',
#          'volume_7day': '56224.25563717'},
#  'BTG': {'24H_fluctate': '-420',
#          '24H_fluctate_rate': '-2.83',
#          'average_price': '14472.2513',
#          'buy_price': '14400',
#          'closing_price': '14420',
#          'max_price': '15040',
#          'min_price': '12970',
#          'opening_price': '14840',
#          'sell_price': '14420',
#          'units_traded': '22894001.48223701',
#          'volume_1day': '22894001.48223701',
#          'volume_7day': '99818762.59154794'},
#  'BZNT': {'24H_fluctate': '-0.7',
#           '24H_fluctate_rate': '-2.47',
#           'average_price': '27.9295',
#           'buy_price': '27.5',
#           'closing_price': '27.6',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '28.3',
#           'sell_price': '27.6',
#           'units_traded': '34999398.78911007',
#           'volume_1day': '34999398.78911007',
#           'volume_7day': '191678148.402933452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-2.80',
#          'average_price': '34.5503',
#          'buy_price': '34',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '35.6',
#          'sell_price': '34.6',
#          'units_traded': '4582139.50945042',
#          'volume_1day': '4582139.50945042',
#          'volume_7day': '36246203.738995702860476475'},
#  'CTXC': {'24H_fluctate': '-5',
#           '24H_fluctate_rate': '-4.16',
#           'average_price': '118.0274',
#           'buy_price': '115',
#           'closing_price': '115',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '120',
#           'sell_price': '117',
#           'units_traded': '1319727.68271294',
#           'volume_1day': '1319727.68271294',
#           'volume_7day': '11470176.075621014673753123'},
#  'DASH': {'24H_fluctate': '-2950',
#           '24H_fluctate_rate': '-3.15',
#           'average_price': '90640.7063',
#           'buy_price': '90300',
#           'closing_price': '90600',
#           'max_price': '93550',
#           'min_price': '88100',
#           'opening_price': '93550',
#           'sell_price': '90700',
#           'units_traded': '3624164.92893308',
#           'volume_1day': '3624164.92893308',
#           'volume_7day': '32148139.18272674'},
#  'ELF': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '4.68',
#          'average_price': '132.2722',
#          'buy_price': '134',
#          'closing_price': '134',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '128',
#          'sell_price': '135',
#          'units_traded': '5163412.69015202',
#          'volume_1day': '5163412.69015202',
#          'volume_7day': '18482823.862288335405889591'},
#  'ENJ': {'24H_fluctate': '-1.7',
#          '24H_fluctate_rate': '-3.79',
#          'average_price': '44.0063',
#          'buy_price': '43.1',
#          'closing_price': '43.1',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.8',
#          'sell_price': '43.3',
#          'units_traded': '3399676.75639568',
#          'volume_1day': '3399676.75639568',
#          'volume_7day': '22984483.064958192816118614'},
#  'EOS': {'24H_fluctate': '-143',
#          '24H_fluctate_rate': '-4.56',
#          'average_price': '3045.5377',
#          'buy_price': '2989',
#          'closing_price': '2989',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3132',
#          'sell_price': '2993',
#          'units_traded': '2399384.30085612',
#          'volume_1day': '2399384.30085612',
#          'volume_7day': '22709185.28753151'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-265',
#          '24H_fluctate_rate': '-4.45',
#          'average_price': '5776.1975',
#          'buy_price': '5680',
#          'closing_price': '5680',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5945',
#          'sell_price': '5685',
#          'units_traded': '527858.95759124',
#          'volume_1day': '527858.95759124',
#          'volume_7day': '1867450.437014439873039507'},
#  'ETH': {'24H_fluctate': '-3900',
#          '24H_fluctate_rate': '-2.28',
#          'average_price': '168119.3172',
#          'buy_price': '166700',
#          'closing_price': '166700',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '170600',
#          'sell_price': '166800',
#          'units_traded': '580906.09235675',
#          'volume_1day': '580906.09235675',
#          'volume_7day': '1972433.069420816188046675'},
#  'ETHOS': {'24H_fluctate': '-14',
#            '24H_fluctate_rate': '-1.25',
#            'average_price': '1107.6905',
#            'buy_price': '1095',
#            'closing_price': '1099',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1113',
#            'sell_price': '1099',
#            'units_traded': '255440.14607046',
#            'volume_1day': '255440.14607046',
#            'volume_7day': '6297063.40976809'},
#  'GNT': {'24H_fluctate': '-1.4',
#          '24H_fluctate_rate': '-1.80',
#          'average_price': '76.4752',
#          'buy_price': '75.6',
#          'closing_price': '76',
#          'max_price': '77.8',
#          'min_price': '75.3',
#          'opening_price': '77.4',
#          'sell_price': '76',
#          'units_traded': '1033620.98780724',
#          'volume_1day': '1033620.98780724',
#          'volume_7day': '37331129.307445753986240579'},
#  'GTO': {'24H_fluctate': '-1.1',
#          '24H_fluctate_rate': '-1.50',
#          'average_price': '74.0844',
#          'buy_price': '71.9',
#          'closing_price': '72',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '72.9',
#          'units_traded': '2273063.76542207',
#          'volume_1day': '2273063.76542207',
#          'volume_7day': '24859136.65975879'},
#  'HC': {'24H_fluctate': '-7',
#         '24H_fluctate_rate': '-0.48',
#         'average_price': '1444.7',
#         'buy_price': '1414',
#         'closing_price': '1433',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1440',
#         'sell_price': '1433',
#         'units_traded': '81008.03733315',
#         'volume_1day': '81008.03733315',
#         'volume_7day': '886944.28807459'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '294.8687',
#          'buy_price': '287',
#          'closing_price': '287',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '287',
#          'sell_price': '291',
#          'units_traded': '2154868.84316089',
#          'volume_1day': '2154868.84316089',
#          'volume_7day': '5021510.732627308297395376'},
#  'INS': {'24H_fluctate': '28',
#          '24H_fluctate_rate': '8.56',
#          'average_price': '339.5987',
#          'buy_price': '355',
#          'closing_price': '355',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '327',
#          'sell_price': '356',
#          'units_traded': '4304646.1878279',
#          'volume_1day': '4304646.1878279',
#          'volume_7day': '11869243.4989243662'},
#  'IOST': {'24H_fluctate': '-0.12',
#           '24H_fluctate_rate': '-1.85',
#           'average_price': '6.3295',
#           'buy_price': '6.24',
#           'closing_price': '6.35',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.47',
#           'sell_price': '6.38',
#           'units_traded': '422057291.21543556',
#           'volume_1day': '422057291.21543556',
#           'volume_7day': '1445256292.695034314024641302'},
#  'ITC': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '136.6905',
#          'buy_price': '135',
#          'closing_price': '136',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '140',
#          'sell_price': '136',
#          'units_traded': '1478489.60879136',
#          'volume_1day': '1478489.60879136',
#          'volume_7day': '17514151.853270639705758781'},
#  'KNC': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-3.80',
#          'average_price': '179.4902',
#          'buy_price': '176',
#          'closing_price': '177',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '184',
#          'sell_price': '177',
#          'units_traded': '806506.64795387',
#          'volume_1day': '806506.64795387',
#          'volume_7day': '7210520.168590646089975132'},
#  'LINK': {'24H_fluctate': '55',
#           '24H_fluctate_rate': '14.98',
#           'average_price': '403.7085',
#           'buy_price': '422',
#           'closing_price': '422',
#           'max_price': '446',
#           'min_price': '362',
#           'opening_price': '367',
#           'sell_price': '423',
#           'units_traded': '12420154.97765239',
#           'volume_1day': '12420154.97765239',
#           'volume_7day': '16693362.550525832613136453'},
#  'LOOM': {'24H_fluctate': '-2.2',
#           '24H_fluctate_rate': '-3.89',
#           'average_price': '57.6785',
#           'buy_price': '54.3',
#           'closing_price': '54.3',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.5',
#           'sell_price': '54.9',
#           'units_traded': '23610390.80646854',
#           'volume_1day': '23610390.80646854',
#           'volume_7day': '46943981.244299057015732253'},
#  'LRC': {'24H_fluctate': '-29',
#          '24H_fluctate_rate': '-4.92',
#          'average_price': '576.465',
#          'buy_price': '560',
#          'closing_price': '560',
#          'max_price': '595',
#          'min_price': '560',
#          'opening_price': '589',
#          'sell_price': '561',
#          'units_traded': '141985.74528059',
#          'volume_1day': '141985.74528059',
#          'volume_7day': '2925430.287171617643527395'},
#  'LTC': {'24H_fluctate': '-1020',
#          '24H_fluctate_rate': '-2.78',
#          'average_price': '35925.1464',
#          'buy_price': '35600',
#          'closing_price': '35580',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36600',
#          'sell_price': '35660',
#          'units_traded': '11843.73409976',
#          'volume_1day': '11843.73409976',
#          'volume_7day': '176033.50952017'},
#  'MCO': {'24H_fluctate': '-23',
#          '24H_fluctate_rate': '-0.88',
#          'average_price': '2583.8452',
#          'buy_price': '2582',
#          'closing_price': '2590',
#          'max_price': '2637',
#          'min_price': '2533',
#          'opening_price': '2613',
#          'sell_price': '2622',
#          'units_traded': '804476.50340361',
#          'volume_1day': '804476.50340361',
#          'volume_7day': '1917859.38617829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.2',
#           '24H_fluctate_rate': '-3.08',
#           'average_price': '69.8337',
#           'buy_price': '68.8',
#           'closing_price': '69',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.2',
#           'sell_price': '69.1',
#           'units_traded': '9125318.49250668',
#           'volume_1day': '9125318.49250668',
#           'volume_7day': '106640941.39980550599621313'},
#  'OCN': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-5.03',
#          'average_price': '3.8437',
#          'buy_price': '3.77',
#          'closing_price': '3.77',
#          'max_price': '4.03',
#          'min_price': '3.67',
#          'opening_price': '3.97',
#          'sell_price': '3.8',
#          'units_traded': '55887125.98978849',
#          'volume_1day': '55887125.98978849',
#          'volume_7day': '1601573929.355513560050201454'},
#  'OMG': {'24H_fluctate': '-35',
#          '24H_fluctate_rate': '-2.07',
#          'average_price': '1645.332',
#          'buy_price': '1640',
#          'closing_price': '1654',
#          'max_price': '1689',
#          'min_price': '1612',
#          'opening_price': '1689',
#          'sell_price': '1655',
#          'units_traded': '1241984.85614469',
#          'volume_1day': '1241984.85614469',
#          'volume_7day': '10926171.768021818906013623'},
#  'PAY': {'24H_fluctate': '-60',
#          '24H_fluctate_rate': '-3.33',
#          'average_price': '1787.0385',
#          'buy_price': '1740',
#          'closing_price': '1740',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1800',
#          'sell_price': '1741',
#          'units_traded': '190811.37610496',
#          'volume_1day': '190811.37610496',
#          'volume_7day': '8366627.260588602801787014'},
#  'PIVX': {'24H_fluctate': '-44',
#           '24H_fluctate_rate': '-4.58',
#           'average_price': '939.2163',
#           'buy_price': '918',
#           'closing_price': '916',
#           'max_price': '972',
#           'min_price': '914',
#           'opening_price': '960',
#           'sell_price': '926',
#           'units_traded': '144131.19080544',
#           'volume_1day': '144131.19080544',
#           'volume_7day': '10439928.69344645'},
#  'PLY': {'24H_fluctate': '-1.3',
#          '24H_fluctate_rate': '-3.35',
#          'average_price': '38.1588',
#          'buy_price': '37.1',
#          'closing_price': '37.4',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '38.7',
#          'sell_price': '37.4',
#          'units_traded': '10230132.4525848',
#          'volume_1day': '10230132.4525848',
#          'volume_7day': '109028021.265338524'},
#  'POLY': {'24H_fluctate': '-7',
#           '24H_fluctate_rate': '-4.32',
#           'average_price': '157.3109',
#           'buy_price': '155',
#           'closing_price': '155',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '162',
#           'sell_price': '157',
#           'units_traded': '1154843.10119114',
#           'volume_1day': '1154843.10119114',
#           'volume_7day': '9948804.158797255355654461'},
#  'POWR': {'24H_fluctate': '-17',
#           '24H_fluctate_rate': '-3.14',
#           'average_price': '528.721',
#           'buy_price': '517',
#           'closing_price': '523',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '540',
#           'sell_price': '523',
#           'units_traded': '420065.73705944',
#           'volume_1day': '420065.73705944',
#           'volume_7day': '6124552.71916919'},
#  'PPT': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-0.59',
#          'average_price': '1662.8678',
#          'buy_price': '1651',
#          'closing_price': '1670',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1680',
#          'sell_price': '1669',
#          'units_traded': '37131.825',
#          'volume_1day': '37131.825',
#          'volume_7day': '689672.87576665'},
#  'PST': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-4.38',
#          'average_price': '111.5105',
#          'buy_price': '109',
#          'closing_price': '109',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '114',
#          'sell_price': '110',
#          'units_traded': '809377.14936885',
#          'volume_1day': '809377.14936885',
#          'volume_7day': '9450797.360011780616582618'},
#  'QTUM': {'24H_fluctate': '-86',
#           '24H_fluctate_rate': '-3.35',
#           'average_price': '2494.8289',
#           'buy_price': '2478',
#           'closing_price': '2480',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2566',
#           'sell_price': '2491',
#           'units_traded': '748973.45074719',
#           'volume_1day': '748973.45074719',
#           'volume_7day': '3120235.07498459'},
#  'RDN': {'24H_fluctate': '-40',
#          '24H_fluctate_rate': '-11.90',
#          'average_price': '311.6047',
#          'buy_price': '294',
#          'closing_price': '296',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '336',
#          'sell_price': '297',
#          'units_traded': '7261349.25059332',
#          'volume_1day': '7261349.25059332',
#          'volume_7day': '25543637.518105808601343468'},
#  'REP': {'24H_fluctate': '-2800',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '96872.8763',
#          'buy_price': '95400',
#          'closing_price': '95400',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98200',
#          'sell_price': '96000',
#          'units_traded': '3599.78825605',
#          'volume_1day': '3599.78825605',
#          'volume_7day': '94083.508281661535728315'},
#  'RNT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.08',
#          'average_price': '145.583',
#          'buy_price': '140',
#          'closing_price': '141',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '144',
#          'sell_price': '141',
#          'units_traded': '82941684.96287222',
#          'volume_1day': '82941684.96287222',
#          'volume_7day': '186601931.257915597667727845'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.13',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.13',
#          'sell_price': '0.13',
#          'units_traded': '42619038546.34593077',
#          'volume_1day': '42619038546.34593077',
#          'volume_7day': '217152860621.220243198764699686'},
#  'SALT': {'24H_fluctate': '-15',
#           '24H_fluctate_rate': '-5.37',
#           'average_price': '273.6348',
#           'buy_price': '264',
#           'closing_price': '264',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '279',
#           'sell_price': '267',
#           'units_traded': '1445333.68021115',
#           'volume_1day': '1445333.68021115',
#           'volume_7day': '12808848.92732145'},
#  'SNT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '116.4897',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '116',
#          'sell_price': '116',
#          'units_traded': '1685691.35883482',
#          'volume_1day': '1685691.35883482',
#          'volume_7day': '23968638.404160067213343892'},
#  'STEEM': {'24H_fluctate': '-18',
#            '24H_fluctate_rate': '-0.96',
#            'average_price': '1825.259',
#            'buy_price': '1806',
#            'closing_price': '1838',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1856',
#            'sell_price': '1838',
#            'units_traded': '74843.7044933',
#            'volume_1day': '74843.7044933',
#            'volume_7day': '1363204.4297473'},
#  'STRAT': {'24H_fluctate': '-33',
#            '24H_fluctate_rate': '-1.15',
#            'average_price': '2842.6935',
#            'buy_price': '2822',
#            'closing_price': '2822',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2855',
#            'sell_price': '2882',
#            'units_traded': '24980.94559972',
#            'volume_1day': '24980.94559972',
#            'volume_7day': '486369.3177285'},
#  'THETA': {'24H_fluctate': '-1.3',
#            '24H_fluctate_rate': '-2.25',
#            'average_price': '57.986',
#            'buy_price': '56.3',
#            'closing_price': '56.4',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.7',
#            'sell_price': '56.4',
#            'units_traded': '18351633.1023032',
#            'volume_1day': '18351633.1023032',
#            'volume_7day': '91931853.277988079266342968'},
#  'TMTG': {'24H_fluctate': '-0.31',
#           '24H_fluctate_rate': '-3.70',
#           'average_price': '8.2448',
#           'buy_price': '8.05',
#           'closing_price': '8.06',
#           'max_price': '8.41',
#           'min_price': '8.03',
#           'opening_price': '8.37',
#           'sell_price': '8.09',
#           'units_traded': '206905858.02808141',
#           'volume_1day': '206905858.02808141',
#           'volume_7day': '1483684407.505064787452122042'},
#  'TRUE': {'24H_fluctate': '22',
#           '24H_fluctate_rate': '7.56',
#           'average_price': '306.9154',
#           'buy_price': '311',
#           'closing_price': '313',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '291',
#           'sell_price': '313',
#           'units_traded': '2382658.35263346',
#           'volume_1day': '2382658.35263346',
#           'volume_7day': '8791779.888040234515508228'},
#  'TRX': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '1.35',
#          'average_price': '22.4343',
#          'buy_price': '22.3',
#          'closing_price': '22.4',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '22.1',
#          'sell_price': '22.4',
#          'units_traded': '222238999.52420231',
#          'volume_1day': '222238999.52420231',
#          'volume_7day': '934839142.87073275'},
#  'VET': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-3.02',
#          'average_price': '7.193',
#          'buy_price': '7.06',
#          'closing_price': '7.06',
#          'max_price': '7.35',
#          'min_price': '7.06',
#          'opening_price': '7.28',
#          'sell_price': '7.13',
#          'units_traded': '8069066.75728701',
#          'volume_1day': '8069066.75728701',
#          'volume_7day': '72433394.02486151956123794'},
#  'WAVES': {'24H_fluctate': '-15',
#            '24H_fluctate_rate': '-0.43',
#            'average_price': '3484.2318',
#            'buy_price': '3441',
#            'closing_price': '3459',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3474',
#            'sell_price': '3477',
#            'units_traded': '172733.25191167',
#            'volume_1day': '172733.25191167',
#            'volume_7day': '2676139.03950588'},
#  'WAX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '105.6142',
#          'buy_price': '104',
#          'closing_price': '105',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '107',
#          'sell_price': '105',
#          'units_traded': '853831.72129347',
#          'volume_1day': '853831.72129347',
#          'volume_7day': '17517731.67024218'},
#  'WET': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.71',
#          'average_price': '14.0787',
#          'buy_price': '13.9',
#          'closing_price': '13.9',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14',
#          'sell_price': '14',
#          'units_traded': '18451960.44528711',
#          'volume_1day': '18451960.44528711',
#          'volume_7day': '194603270.091909116950969508'},
#  'WTC': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '0.55',
#          'average_price': '1285.9103',
#          'buy_price': '1268',
#          'closing_price': '1275',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1268',
#          'sell_price': '1275',
#          'units_traded': '227217.89657532',
#          'volume_1day': '227217.89657532',
#          'volume_7day': '2367938.752517056649794688'},
#  'XEM': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-1.36',
#          'average_price': '73.2275',
#          'buy_price': '72.3',
#          'closing_price': '72.3',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '73.3',
#          'sell_price': '72.5',
#          'units_traded': '2041313.72985356',
#          'volume_1day': '2041313.72985356',
#          'volume_7day': '21621786.25553651'},
#  'XLM': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.07',
#          'average_price': '128.1431',
#          'buy_price': '126',
#          'closing_price': '126',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4803094.94522867',
#          'volume_1day': '4803094.94522867',
#          'volume_7day': '47690901.83275804'},
#  'XMR': {'24H_fluctate': '-1650',
#          '24H_fluctate_rate': '-2.88',
#          'average_price': '55910.2616',
#          'buy_price': '55450',
#          'closing_price': '55450',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '57100',
#          'sell_price': '55450',
#          'units_traded': '13658379.85519034',
#          'volume_1day': '13658379.85519034',
#          'volume_7day': '68494893.497624596036'},
#  'XRP': {'24H_fluctate': '-11',
#          '24H_fluctate_rate': '-2.67',
#          'average_price': '404.0083',
#          'buy_price': '400',
#          'closing_price': '400',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '411',
#          'sell_price': '401',
#          'units_traded': '46133541.97389881',
#          'volume_1day': '46133541.97389881',
#          'volume_7day': '473735993.35841542'},
#  'XVG': {'24H_fluctate': '-0.05',
#          '24H_fluctate_rate': '-0.63',
#          'average_price': '7.8667',
#          'buy_price': '7.75',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.91',
#          'sell_price': '7.85',
#          'units_traded': '5760535.02915987',
#          'volume_1day': '5760535.02915987',
#          'volume_7day': '51375893.93034364'},
#  'ZEC': {'24H_fluctate': '-2100',
#          '24H_fluctate_rate': '-3.12',
#          'average_price': '65696.1285',
#          'buy_price': '64800',
#          'closing_price': '65000',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67100',
#          'sell_price': '65000',
#          'units_traded': '36071.96564304',
#          'volume_1day': '36071.96564304',
#          'volume_7day': '33445009.22462229'},
#  'ZIL': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.76',
#          'average_price': '22.3684',
#          'buy_price': '22.1',
#          'closing_price': '22.2',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.6',
#          'sell_price': '22.2',
#          'units_traded': '19260971.44188188',
#          'volume_1day': '19260971.44188188',
#          'volume_7day': '456983998.809213354635'},
#  'ZRX': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-0.82',
#          'average_price': '363.79',
#          'buy_price': '358',
#          'closing_price': '359',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '362',
#          'sell_price': '361',
#          'units_traded': '1008506.64805099',
#          'volume_1day': '1008506.64805099',
#          'volume_7day': '5916196.922581677377380573'},
#  'date': '1546568838932'}

# %%
# 아래에 코드를 작성하세요.


for key, value in currency.items():
    if type(value)== type(dict()):
        opening = value["opening_price"]
        low = value["min_price"]
        high = value["max_price"]
    
        if float(opening) + (float(high) - float(low)) > float(high):
            print(f"{key} 상승장")
        else:
            print(f"{key} 하락장")
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 상승장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 상승장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 상승장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ROM 상승장
# AMO 상승장

# %%
# value값이 딕셔너리인 항목만 선택한다

for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value["max_price"]) - float(value["min_price"])
        if float(value['opening_price']) + bdp > float(value["max_price"]):
            print(f'{key:5} 상승장')   # 5글자의 key와 value로 묶는다
        else:
            print(f'{key:5} 하락장')
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장
